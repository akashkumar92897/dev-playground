# %% [markdown]
# Indexing of String with index or reverse index

# %%
mystring = "HELLO WORLD"

# %%
mystring
# Out:
# 'HELLO WORLD'

# %%
mystring[0]
# Out:
# 'H'

# %%
mystring[7]
# Out:
# 'O'

# %%
mystring[9]
# Out:
# 'L'

# %%
mystring[-2]
# Out:
# 'L'

# %%
mystring[-11]
# Out:
# 'H'

# %% [markdown]
# Slicing of String

# %%
mystring = 'abcdefghijklm'

# %%
mystring
# Out:
# 'abcdefghijklm'

# %%
mystring [2]
# Out:
# 'c'

# %%
mystring [2:]
# Out:
# 'cdefghijklm'

# %%
mystring [:3]
# Out:
# 'abc'

# %%
mystring [3:6]
# Out:
# 'def'

# %%
mystring [1:4]
# Out:
# 'bcd'

# %%
mystring [::]
# Out:
# 'abcdefghijklm'

# %%
mystring [::2]
# Out:
# 'acegikm'

# %%
mystring [::4]
# Out:
# 'aeim'

# %%
mystring [2:7:2]
# Out:
# 'ceg'

# %% [markdown]
# Reverse a String

# %%
mystring [::-1]
# Out:
# 'mlkjihgfedcba'
