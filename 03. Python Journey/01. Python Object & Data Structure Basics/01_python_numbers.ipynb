# %%
1 + 1
# Out:
# 2

# %%
5 - 3
# Out:
# 2

# %%
2 * 9
# Out:
# 18

# %%
8 / 2
# Out:
# 4.0

# %% [markdown]
# Modulo or "Mod" Operator

# %%
7 % 4
# Out:
# 3

# %%
50 % 5
# Out:
# 0

# %% [markdown]
# To check a number is even or odd => Take modulo with 2, if it return 0 => Even, else => odd

# %%
8 % 2
# Out:
# 0

# %%
5 % 2
# Out:
# 1

# %% [markdown]
# Power Operator = **

# %%
2 ** 3
# Out:
# 8

# %%
2 + 10 * 10 + 3
# Out:
# 105

# %%
(2 + 10) * (10 + 3)
# Out:
# 156

# %%
1 / 2
# Out:
# 0.5
