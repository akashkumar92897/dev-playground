# %%
'Hello'
# Out:
# 'Hello'

# %%
"World"
# Out:
# 'World'

# %%
'This is also a String'
# Out:
# 'This is also a String'

# %%
"I'm going on a run"
# Out:
# "I'm going on a run"

# %%
print ('Hello World')
# Out:
# Hello World

# %%
print ("Hello Python")
# Out:
# Hello Python

# %%
print ("Hello \n Jupyter")
# Out:
# Hello
#  Jupyter

# %%
print ("Hello \nJupyter")
# Out:
# Hello
# Jupyter

# %%
print ("Hello \tJupyter")
# Out:
# Hello 	Jupyter

# %%
len ("Hello")
# Out:
# 5

# %%
len ("Hello World")
# Out:
# 11
